# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from torchvision import datasets, transforms

# %%
TRAIN_DIR = "../train"

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

dataset = datasets.ImageFolder(
    root=TRAIN_DIR,
    transform=transform
)

print("Total images:", len(dataset))
print("Classes:", dataset.classes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-311061271.py in <cell line: 0>()
#       1 TRAIN_DIR = "../train"
#       2
# ----> 3 transform = transforms.Compose([
#       4     transforms.Resize((224, 224)),
#       5     transforms.ToTensor()
#
# NameError: name 'transforms' is not defined

# %%
from collections import Counter

labels = [label for _, label in dataset]
class_counts = Counter(labels)

class_names = dataset.classes
counts = [class_counts[i] for i in range(len(class_names))]

plt.figure(figsize=(8,5))
plt.bar(class_names, counts)
plt.xticks(rotation=20)
plt.title("Class Distribution in Alzheimer MRI Dataset")
plt.ylabel("Number of Images")
plt.xlabel("Class")
plt.show()

# %%
def show_samples(dataset, class_idx, num_samples=5):
    plt.figure(figsize=(15,3))
    count = 0

    for img, label in dataset:
        if label == class_idx:
            plt.subplot(1, num_samples, count+1)
            plt.imshow(img.permute(1,2,0))
            plt.axis('off')
            count += 1
            if count == num_samples:
                break
    plt.show()

for idx, class_name in enumerate(dataset.classes):
    print(f"Samples from class: {class_name}")
    show_samples(dataset, idx)
# Out:
# Samples from class: Mild Impairment
# Samples from class: Moderate Impairment
# Samples from class: No Impairment
# Samples from class: Very Mild Impairment

# %% [markdown]
# ### Dataset Observations
#
# - The dataset contains 10,240 MRI images distributed across four Alzheimer’s stages.
# - Class imbalance is observed, with certain stages having more samples.
# - MRI images show visible structural variations across disease stages.
# - Images are already well-centered and suitable for deep learning models.
